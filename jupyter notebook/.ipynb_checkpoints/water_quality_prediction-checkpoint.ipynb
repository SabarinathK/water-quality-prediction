# %% [markdown]
# # Water quality prediction

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier
from sklearn.svm import SVC

import joblib as jb


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data Read

# %%
df=pd.read_csv('water_potability.csv')

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %% [markdown]
#  1 means Potable(good for drinking) and 0 means Not potable.(not a drinking water)

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.nunique()
# Out:
# ph                 2785
# Hardness           3276
# Solids             3276
# Chloramines        3276
# Sulfate            2495
# Conductivity       3276
# Organic_carbon     3276
# Trihalomethanes    3114
# Turbidity          3276
# Potability            2
# dtype: int64

# %%
# Finding Null values
null=df.isnull().sum()
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ph , Sulfate,Trihalomethanes columns has null values
#
# # Replacing null value with median

# %%
df=df.fillna(df.median())

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %% [markdown]
# ### FInding Outliers

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
for column in df.columns[:-1]:
    plt.figure(figsize=(10,5))
    sns.boxplot(x=(column),data=df)

# %% [markdown]
# # handling oultier

# %%
for column in df.columns[:-1]:
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_range=Q1-(IQR*1.5)
    upper_range=Q3+(IQR*1.5)
    df[column]=np.where(df[column]<lower_range,lower_range,df[column])
    df[column]=np.where(df[column]>upper_range,upper_range,df[column])

# %%
for column in df.columns[:-1]:
    plt.figure(figsize=(10,5))
    sns.boxplot(x=(column),data=df)

# %%
for column in df.columns[:-1]:
    plt.figure(figsize=(10,5))
    sns.histplot(x=(column),data=df)

# %% [markdown]
# ### dataset balanced or imbalanced

# %%
df['Potability'].value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %% [markdown]
# dataset is imbalanced

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # data separation

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
y=df['Potability'].copy()
X=df.drop('Potability',axis=1).copy()

# %%
X.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0  7.036752  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.889107  129.422921  18630.057858     6.635246  333.073546    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884  333.073546    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       10.379783        86.990970   2.963135
# 1       15.180013        56.329076   4.500656
# 2       16.868637        66.420093   3.055934
# 3       18.436524       100.341674   4.628771
# 4       11.558279        31.997993   4.075075

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Potability, dtype: int64

# %%
y.value_counts()
# Out:
# 0    1998
# 1    1278
# Name: Potability, dtype: int64

# %%
from collections import Counter
from imblearn.over_sampling import RandomOverSampler 
ros = RandomOverSampler()
X_res, y_res = ros.fit_resample(X, y)
print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Resampled dataset shape Counter({0: 1998, 1: 1998})

# %%
y_res.value_counts()
# Out:
# 0    1998
# 1    1998
# Name: Potability, dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X_res,y_res,train_size=0.7,random_state=356)

# %%
X_train.shape,X_test.shape
# Out:
# ((2797, 9), (1199, 9))

# %%
y_train.shape,y_test.shape
# Out:
# ((2797,), (1199,))

# %%
y_res.value_counts()
# Out:
# 0    1998
# 1    1998
# Name: Potability, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier
from sklearn.svm import SVC

# %%
from sklearn.metrics import classification_report, plot_confusion_matrix

# %%
def algo(model):
    model=model
    model.fit(X_res,y_res)
    y_pred=model.predict(X_test)
    print('____________________________________\n',model,'Report\n____________________________________')
    print('train_accuracy',model.score(X_res,y_res)*100)
    print('test_accuracy',model.score(X_test,y_test)*100)
    print(classification_report(y_pred,y_test))
    print(plot_confusion_matrix(model,X_test,y_test))

# %%
model=LogisticRegression()
algo(model)
# Out:
# ____________________________________
#  LogisticRegression() Report
# ____________________________________
# train_accuracy 50.12512512512512
# test_accuracy 50.0417014178482
#               precision    recall  f1-score   support
#
#            0       0.55      0.51      0.53       663
#            1       0.45      0.49      0.46       536
#
#     accuracy                           0.50      1199
#    macro avg       0.50      0.50      0.50      1199
# weighted avg       0.50      0.50      0.50      1199
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x00000225AD025DC0>

# %%
algo(DecisionTreeClassifier())
# Out:
# ____________________________________
#  DecisionTreeClassifier() Report
# ____________________________________
# train_accuracy 100.0
# test_accuracy 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       616
#            1       1.00      1.00      1.00       583
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x00000225AB6F0970>

# %%
algo(RandomForestClassifier())
jb.dump(model,'model_rfc.pkl')
# Out:
# ____________________________________
#  RandomForestClassifier() Report
# ____________________________________
# train_accuracy 100.0
# test_accuracy 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       616
#            1       1.00      1.00      1.00       583
#
#     accuracy                           1.00      1199
#    macro avg       1.00      1.00      1.00      1199
# weighted avg       1.00      1.00      1.00      1199
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x00000225AB772EB0>
# ['model_rfc.pkl']

# %%
algo(AdaBoostClassifier())
# Out:
# ____________________________________
#  AdaBoostClassifier() Report
# ____________________________________
# train_accuracy 62.312312312312315
# test_accuracy 60.71726438698916
#               precision    recall  f1-score   support
#
#            0       0.65      0.61      0.63       659
#            1       0.56      0.60      0.58       540
#
#     accuracy                           0.61      1199
#    macro avg       0.61      0.61      0.61      1199
# weighted avg       0.61      0.61      0.61      1199
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x00000225AE093C40>

# %%
algo(GradientBoostingClassifier())
# Out:
# ____________________________________
#  GradientBoostingClassifier() Report
# ____________________________________
# train_accuracy 76.07607607607608
# test_accuracy 76.14678899082568
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78       692
#            1       0.69      0.79      0.74       507
#
#     accuracy                           0.76      1199
#    macro avg       0.76      0.77      0.76      1199
# weighted avg       0.77      0.76      0.76      1199
#
# <sklearn.metrics._plot.confusion_matrix.ConfusionMatrixDisplay object at 0x00000225ACF7FE80>

# %% [markdown]
#  Random Forest is Good when compare to other model performance
#  so Random forest is saved
